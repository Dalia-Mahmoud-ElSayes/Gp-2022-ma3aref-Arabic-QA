# %%
# Import libraries
try:
  import textaugment, gensim
except ModuleNotFoundError:
  # !pip -q install textaugment gensim
  import textaugment, gensim
# Out:
#      |████████████████████████████████| 55 kB 2.1 MB/s
#      |████████████████████████████████| 42 kB 1.3 MB/s
#      |████████████████████████████████| 1.3 MB 10.9 MB/s
#      |████████████████████████████████| 53 kB 2.0 MB/s
#      |████████████████████████████████| 65 kB 3.5 MB/s
# ...

# %%
# Import NLRK and download data
import nltk
nltk.download(['wordnet','punkt','averaged_perceptron_tagger'])
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
# !wget https://archive.org/download/full_grams_cbow_300_twitter/full_grams_cbow_300_twitter.zip
# !unzip full_grams_cbow_300_twitter.zip

#----------------------------------------------------------------------------------------------

#!wget https://archive.org/details/full_grams_cbow_300_wiki/full_grams_cbow_300_wiki.zip
#!unzip full_grams_cbow_300_wiki.zip
# Out:
# --2022-05-26 20:42:21--  https://archive.org/download/full_grams_cbow_300_twitter/full_grams_cbow_300_twitter.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia902803.us.archive.org/15/items/full_grams_cbow_300_twitter/full_grams_cbow_300_twitter.zip [following]
# --2022-05-26 20:42:22--  https://ia902803.us.archive.org/15/items/full_grams_cbow_300_twitter/full_grams_cbow_300_twitter.zip
# Resolving ia902803.us.archive.org (ia902803.us.archive.org)... 207.241.232.103
# Connecting to ia902803.us.archive.org (ia902803.us.archive.org)|207.241.232.103|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3325529808 (3.1G) [application/zip]
# Saving to: ‘full_grams_cbow_300_twitter.zip’
#
# full_grams_cbow_300 100%[===================>]   3.10G   365KB/s    in 2h 35m
#
# ...

# %%
#import gensim
from gensim.models import Word2Vec, KeyedVectors
from sklearn.decomposition import PCA


import gensim
import re
import numpy as np
from nltk import ngrams

# %%
#model = gensim.models.KeyedVectors.load_word2vec_format('./GoogleNews-vectors-negative300.bin.gz', binary=True)
model = gensim.models.Word2Vec.load('full_grams_cbow_300_twitter.mdl')
#model = gensim.models.Word2Vec.load("/content/drive/MyDrive/Rule based data /full_grams_cbow_300_wiki/full_grams_cbow_300_wiki.mdl")
#model = gensim.models.Word2Vec.load('full_grams_cbow_300_wiki.mdl')

# %%
from textaugment import Word2vec
t = Word2vec(model=model)
output = t.augment('''
هل يجوز الإفطار للحامل أو المرضع إذا خافتا من الصيام على الجنين أو الرضيع؟ وهل يلزمهما القضاء والفدية أو يلزمهما أحدهما؟
''')

# %%
print(output)
# Out:
# ماذا هل_يجوز الإفطار والمساج أو معهافقالت إذا خافتا من صيام على الجنين أو الرضيع؟ ولماذا العافيه_وبقاء_النعم القانون والفدية أو يلزمهما أحدهما؟

# %%
q = t.augment('''
هل حرم الله عمل المرأه
''')

# %%
print(q)
# Out:
# لماذا حرم الله عملنا المرأه
